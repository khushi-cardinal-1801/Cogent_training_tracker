# %%
from langchain_core.documents import Document
print("kernel setup completely")
# Out:
# kernel setup completely

# %%
docs=Document(
    page_content="we are initiating with RAG playlist, and we will get the best understnading out of it",
    metadata={
        "author":"Khushi Aggarwal",
        "time":"07-Aug-2026",
        "published":"local"
    }
    
)

# %%
print(docs)
# Out:
# page_content='we are initiating with RAG playlist, and we will get the best understnading out of it' metadata={'author': 'Khushi Aggarwal', 'time': '07-Aug-2026', 'published': 'local'}

# %%
##create simple text file
import os
os.makedirs("..data/text_file", exist_ok=True)

# %%
with open("../data/sample_text.txt", "r", encoding="utf-8") as file:
    text = file.read()

print(text)
# Out:
# A dog is a loyal and friendly animal.
# It is one of the most popular pets in the world.
# Dogs help people by guarding homes and protecting families.
# They have a strong sense of smell and hearing.
# Dogs are also used by the police and rescue teams.
# They enjoy playing, running, and spending time with their owners.
# Dogs eat food such as meat, rice, vegetables, and specially prepared dog food.
# They are intelligent animals and can learn many commands.
# A dog teaches us the values of love, loyalty, and companionship.
# We should always take good care of dogs and treat them with kindness.

# %%
from langchain_community.document_loaders import TextLoader
loader=TextLoader("../data/sample_text.txt", encoding="utf-8")
document=loader.load()
print(document)
# Out:
# [Document(metadata={'source': '../data/sample_text.txt'}, page_content='A dog is a loyal and friendly animal.\nIt is one of the most popular pets in the world.\nDogs help people by guarding homes and protecting families.\nThey have a strong sense of smell and hearing.\nDogs are also used by the police and rescue teams.\nThey enjoy playing, running, and spending time with their owners.\nDogs eat food such as meat, rice, vegetables, and specially prepared dog food.\nThey are intelligent animals and can learn many commands.\nA dog teaches us the values of love, loyalty, and companionship.\nWe should always take good care of dogs and treat them with kindness.')]

# %%
from langchain_community.document_loaders import DirectoryLoader
loader=DirectoryLoader("../data",
                       glob="**/*.txt",
                       loader_cls=TextLoader,
                       loader_kwargs={'encoding':'utf-8'},
                       show_progress=False
                       )
document=loader.load()
print(document)
# Out:
# [Document(metadata={'source': '..\\data\\sample_text.txt'}, page_content='A dog is a loyal and friendly animal.\nIt is one of the most popular pets in the world.\nDogs help people by guarding homes and protecting families.\nThey have a strong sense of smell and hearing.\nDogs are also used by the police and rescue teams.\nThey enjoy playing, running, and spending time with their owners.\nDogs eat food such as meat, rice, vegetables, and specially prepared dog food.\nThey are intelligent animals and can learn many commands.\nA dog teaches us the values of love, loyalty, and companionship.\nWe should always take good care of dogs and treat them with kindness.')]

# %%
from langchain_community.document_loaders import PyMuPDFLoader, PyPDFLoader

loader=DirectoryLoader("../data",
                       glob="**/*.pdf",
                       loader_cls=PyPDFLoader,
                       show_progress=False
                       )
document=loader.load()
print(document)
# Out:
# invalid pdf header: b'A dog'
# EOF marker not found
# Error loading file ..\data\sample_pdf.pdf
# ---------------------------------------------------------------------------
# PdfStreamError                            Traceback (most recent call last)
# Cell In[14], line 8
#       4                        glob="**/*.pdf",
#       5                        loader_cls=PyPDFLoader,
#       6                        show_progress=False
#       7                        )
# ----> 8 document=loader.load()
#       9 print(document)
#
# File ~\RAG\venv\Lib\site-packages\langchain_community\document_loaders\directory.py:117, in DirectoryLoader.load(self)
#     115 def load(self) -> List[Document]:
#     116     """Load documents."""
# --> 117     return list(self.lazy_load())
#
# File ~\RAG\venv\Lib\site-packages\langchain_community\document_loaders\directory.py:195, in DirectoryLoader.lazy_load(self)
#     193 else:
#     194     for i in items:
# ...
